# %% [markdown]
# ## Análisis de la metodología para la verificación y construcción de series históricas para el cálculo de la ENFICC en plantas solares fotovoltaicas.
#
# ### Nicolás Meneses Cortés
# #### cod: 201415808

# %% [markdown]
# Se importan las diferentes librerías:

# %%
import os
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Funciones para leer los archivos de data:

# %%
def leerIdeam(ciudad):
    
    base_dir = os.path.join( '.','data')
    output_dir = os.path.join( '.','output')
    #ciudad = 'Valledupar'
    fuente = 'IDEAM'
    serie_csv = os.path.join(base_dir,ciudad,fuente+'.csv')
    serie_ideam = pd.read_csv(serie_csv, sep = ';',
                    encoding='latin-1')
    return serie_ideam

def leerNrel(ciudad):
    base_dir = os.path.join( '.','data')
    output_dir = os.path.join( '.','output')
    #ciudad = 'Valledupar'
    fuente = 'NREL'
    serie_csv = os.path.join(base_dir,ciudad,fuente+'.csv')
    serie_nrel = pd.read_csv(serie_csv, sep = ';',
                    encoding='latin-1')
    return serie_nrel

# %% [markdown]
# ## Punto 1: Función ENFICC

# %% [markdown]
# Se crea la función ENFICC, que tiene como entrada una serie de datos y retorna la ENFICC 99%, además de la seire de la distribución de energía.

# %%
def ENFICC(serie_ener, nombre):
    
    def ghi_mensual(serie_horaria):
        agnos = sorted(serie_horaria['AÑO'].unique())
        ghi_df = pd.DataFrame(columns=["AÑO", "MES", "DIAS", "GHImes"])
        for agno in range(2006,2016):
            for mes in range(1,13):
                nombre_energia = list(serie_horaria)[-1]
                dias = sorted(serie_horaria[(serie_horaria['AÑO'] == agno) &
                            (serie_horaria['MES'] == mes)]["DIA"].unique())
                ghi_mes = serie_horaria.loc[((serie_horaria["AÑO"] == agno)
                                & (serie_horaria["MES"] == mes)),
                                            nombre_energia].sum()/1000
                ghi_dict = {"AÑO":agno, "MES":mes, "DIAS":dias[-1],
                            "GHImes":ghi_mes}
                ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
        return ghi_df

    def ghi_dia(serie_ghi_mensual):
        agnos = sorted(serie_ghi_mensual['AÑO'].unique())
        ghi_df = pd.DataFrame(columns=["AÑO", "MES", "GHIdiario"])
        for agno in range(2006,2016):
            for mes in range(1,13):
                dias = serie_ghi_mensual.loc[((serie_ghi_mensual["AÑO"] == agno)
                                & (serie_ghi_mensual["MES"] == mes))
                                             ,"DIAS"].item()
                ghi_diario = serie_ghi_mensual.loc[(
                    (serie_ghi_mensual["AÑO"] == agno)
                                & (serie_ghi_mensual["MES"] == mes)),
                    "GHImes"].item()/dias
                ghi_dict = {"AÑO":agno, "MES":mes, "GHIdiario":ghi_diario}
                ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
        return ghi_df

    
    ghi_mensual_loc = ghi_mensual(serie_ener)
    ghi_diario_loc = ghi_dia(ghi_mensual_loc)
    serie = sorted(ghi_diario_loc["GHIdiario"])
    numdatos = range(len(serie))
    percentil = 0.01
    enficc = ghi_diario_loc.quantile(q=percentil, 
                                     numeric_only=True)["GHIdiario"]
    print('La ENFICC 99% de ',nombre,' es de ', '%.2f' %(enficc))
    
    return serie, enficc, numdatos

# %% [markdown]
# ## Punto 2: Función para graficar distribución de energía.

# %% [markdown]
# Se crea la función que grafica 3 series de datos (IDEAM, NREL y NREL AJUSTADA)

# %%
def grafica(energia_ideam, energia_nrel, energia_ajustada,agno,mes):
    pylab.xlabel("Datos")
    pylab.ylabel("Energía/Energía Base IDEAM")
    pylab.plot(energia_ideam[2],energia_ideam[0]/energia_ideam[0][0],'-k', label='IDEAM')
    pylab.plot(energia_nrel[2],energia_nrel[0]/energia_ideam[0][0],'-r', label='NREL')
    pylab.plot(energia_ajustada[2],energia_ajustada[0]/energia_ideam[0][0],'-b', label='NREL AJUSTADA')
    pylab.legend(loc='upper left')
    pylab.title('Distribución de energía ')
    #pylab.savefig(os.path.join(output_dir,'valledupar_IDEAM.png'), dpi=600)

# %% [markdown]
# ## Punto 3: Función MCP

# %% [markdown]
# Se crea la función para la metrodología Medición-Correlación-Predicción (MCP), con las series de IDEAM y NREL como entrada. se implementa la función cortar, para obtener un segmento de la serie de 10 años.

# %%
def cortar(serie, agno, mes):
    serie_corta  = serie[(serie['AÑO'] == agno) &
                 (serie['MES'] <= mes)]
    return serie_corta

# %%
def MCP(serieReal, serieSatelite, agno, mes):

    ideamCorta = cortar(serieReal,agno,mes)
    
    
    mediaY = ideamCorta["IDEAM"].mean()
    mediaX = serieSatelite["NREL"].mean()
    desvY = ideamCorta["IDEAM"].std(ddof = 0)
    desvX = serieSatelite["NREL"].std(ddof = 0)
    
    serieAjustada = pd.DataFrame((mediaY-((desvY/desvX)*mediaX)) + ((desvY/desvX)*serieSatelite['NREL']))
    serieAjustada[serieAjustada<0]=0
    serie_ajustada = serieSatelite.copy()
    
    
    del serie_ajustada['NREL']  
   
    serie_ajustada['GHIdiario'] = serieAjustada
        
       
    return serie_ajustada

# %% [markdown]
# ## Punto 4: Funciones de error

# %% [markdown]
# ### Cortar funciones

# %% [markdown]
# Se implementa a función corte para eliminar los años fuera de rango en las series y de esta manera igualar el la cantidad de años contenidos en cada una.

# %%
def corte(serie1, serie2):
    serie1_np = serie1['AÑO'].values
    serie2_np = serie2['AÑO'].values
    max1 = np.max(serie1_np)
    max2 = np.max(serie2_np)
    min1 = np.min(serie1_np)
    min2 = np.min(serie2_np)
    
    if max1 > max2:
        max3 = max2
    else:
        max3 = max1
        
    if min1 < min2:
        min3 = min2
    else:
        min3 = min1
        
    serie1_corta  = serie1[(serie1['AÑO'] >= min3) &
                 (serie1['AÑO'] <= max3)]
    serie2_corta  = serie2[(serie2['AÑO'] >= min3) &
                 (serie2['AÑO'] <= max3)]
    
    return serie1_corta, serie2_corta

# %% [markdown]
# ### RMS (RMSEn)
# Se implementa la función:

# %%
def RMSEn(obs, mod):
         
    obs_np = obs['IDEAM'].values
    mod_np = mod['GHIdiario'].values
    obs_max = np.max(obs_np) 
    mod_min = np.min(mod_np)
    
    error = (np.sqrt(((obs_np-mod_np)**2).mean()))/(obs_max-mod_min)*100
    print('El error RMSEn es: ', '%.2f' %(error), '%')
    return

# %% [markdown]
# ### MBE

# %%
def MBE(obs, mod):
    obs_np = obs['IDEAM'].values
    mod_np = mod['GHIdiario'].values
    
    error = (np.sum(mod_np-obs_np))/(np.sum(obs_np))*100
    print('El error MBE es: ', '%.2f' %(error), '%')
    return

# %% [markdown]
# ### Kolgomorov-smagorinski (KSI%)

# %%
from scipy import stats
def KSI(obs, mod):
    
    error = scipy.stats.mstats.ks_2samp(obs, mod)
    
    print('El valor del test KSI y el p-value son: ', 
          '%.2f, %.2f' %(error[0],error[1]))
    
    return

# %% [markdown]
# ## Código para correr las funciones

# %%
def calcular(ciudad,agno,mes):
    
    serie_ideam = leerIdeam(ciudad)
    serie_nrel = leerNrel(ciudad)
    ajuste = MCP(serie_ideam,serie_nrel,agno,mes)
    
    ideam = ENFICC(serie_ideam, 'Ideam')
    nrel = ENFICC(serie_nrel, 'Nrel')
    ajustada = ENFICC(ajuste, 'Nrel Ajustada')
    
    grafica(ideam,nrel,ajustada,agno,mes)
    
    cortes = corte(serie_ideam,ajuste)
    ideam_corta = cortes[0]
    ajustada_corta = cortes[1]
    RMSEn(ideam_corta, ajustada_corta),MBE(ideam_corta, ajustada_corta),KSI(ideam[0], ajustada[0])

# %% [markdown]
# ## Punto 5: Análisis

# %% [markdown]
# Para analizar la eficacia del método MCP se va a realizar el procedimiento descrito en los anteriores puntos (graficar y calcular errores) para varias zonas y periodos de tiempo.
#
# Se van a tener presentes los periodos de tiempo en los cuales se presentó el fenómeno del niño y de la niña en el territorio colombiano. Se tomaran casos extremos como 2008 (niña), 2010, 2011 y 2015 (niño). También es importante tener presente que dichos fenómenos no tienen un impacto homogeneo en el país, es decir, pueden afectar más a unas regiones que a otras.
#
# En la siguiente figura se presentan los datos tomados del Banco de la República respecto a meses en los que se presentan los fenómenos en dicusión hasta el año 2012:
#
# ![image.png](attachment:image.png) tomado de: https://publicaciones.banrepcultural.org/index.php/emisor/article/view/7891/8271
#
# A partir de la anterior información se trendrán en cuenta los siguientes periódos:
# - ago 07 - mar 09 (Niña)
# - jul 09 - abr 10 (Niño)
# - 15 (Niño)
#
# En primera instancia se trabaja con Medellín, primero se hace un análisis de la eficacia del MCP con diferentes rangos de tiempo. Se calcularan los datos para 1, 3, 6, 9 y 12 meses. A continuación, se presentan los resultados para el año 2008 empezando desde Enero.

# %%
calcular('Medellin',2008,1)
# Out:
# La ENFICC 99% de  Ideam  es de  3.54
# La ENFICC 99% de  Nrel  es de  4.31
# La ENFICC 99% de  Nrel Ajustada  es de  3.36
# El error RMSEn es:  9.88 %
# El error MBE es:  -6.51 %
# El valor del test KSI y el p-value son:  0.30, 0.00

# %%
calcular('Medellin',2008,3)
# Out:
# La ENFICC 99% de  Ideam  es de  3.54
# La ENFICC 99% de  Nrel  es de  4.31
# La ENFICC 99% de  Nrel Ajustada  es de  3.46
# El error RMSEn es:  9.93 %
# El error MBE es:  -3.29 %
# El valor del test KSI y el p-value son:  0.18, 0.04

# %%
calcular('Medellin',2008,6)
# Out:
# La ENFICC 99% de  Ideam  es de  3.54
# La ENFICC 99% de  Nrel  es de  4.31
# La ENFICC 99% de  Nrel Ajustada  es de  3.57
# El error RMSEn es:  9.99 %
# El error MBE es:  -0.37 %
# El valor del test KSI y el p-value son:  0.08, 0.80

# %%
calcular('Medellin',2008,9)
# Out:
# La ENFICC 99% de  Ideam  es de  3.54
# La ENFICC 99% de  Nrel  es de  4.31
# La ENFICC 99% de  Nrel Ajustada  es de  3.60
# El error RMSEn es:  10.01 %
# El error MBE es:  0.45 %
# El valor del test KSI y el p-value son:  0.10, 0.59

# %%
calcular('Medellin',2008,12)
# Out:
# La ENFICC 99% de  Ideam  es de  3.54
# La ENFICC 99% de  Nrel  es de  4.31
# La ENFICC 99% de  Nrel Ajustada  es de  3.54
# El error RMSEn es:  9.96 %
# El error MBE es:  -1.29 %
# El valor del test KSI y el p-value son:  0.11, 0.48

# %% [markdown]
# De los resultados obtenidos es fácil evidenciar que a medida que se aumenta el rango de tiempo gráficamente la serie ajustada de datos tiene tendencia a coincidir con los datos de IDEAM. Otro índice que corrobora lo anterior es el cálculo de la ENFICC, que cuando se toma el año completo coincide en su valor hasta dos decimales (3.54, ENFICC 99% 12 meses).
#
# En cuanto a los resultados de los errores se ve que el el RMSEn se mantiene en el orden de 10%. El MBE disminuye a medida que se aumenta el periodo de tiempo, su valor mínimo se alcanza con los seis primeros meses del año 2008 (MBE = 0.37%). Se puede concluir que con el aumento de tiempo sí hay una disminución en la variación de los datos, sin embargo, depende de las mediciones obtenidas de IDEAM y NREL para cada periodo, ya que tomando el año completo se obtiene un MBE de 1.29%.
#
# Ahora bien, se va a analizar el efecto del fenómeno de la Niña (2008) para Medellín. A continuación, se calcula los datos para los primeros seis meses del 2012, periodo de tiempo en el cual no se presentó ningún fenómeno natural.

# %%
calcular('Medellin',2012,6)
# Out:
# La ENFICC 99% de  Ideam  es de  3.54
# La ENFICC 99% de  Nrel  es de  4.31
# La ENFICC 99% de  Nrel Ajustada  es de  3.41
# El error RMSEn es:  9.88 %
# El error MBE es:  -5.06 %
# El valor del test KSI y el p-value son:  0.25, 0.00

# %% [markdown]
# De los resultados anteriores se destaca que la ENFICC de la serie de datos ajustada presenta valores más bajos en el 2012 a comparación de el 2008, además el error MBE es mayor (MBE = 5.06%).
#
# Para terminar de denotar si hay cambios significativos con los fenómenos, se van a analizar los datos de Uribia en los periódos de el fenómeno del Niño (2010 y 2015) y en el 2012 para tener un punto de referencia. A continuación, se presentan los resultados obtenidos.

# %%
calcular('Uribia',2010,12)
# Out:
# La ENFICC 99% de  Ideam  es de  4.28
# La ENFICC 99% de  Nrel  es de  4.62
# La ENFICC 99% de  Nrel Ajustada  es de  4.00
# El error RMSEn es:  10.99 %
# El error MBE es:  -5.55 %
# El valor del test KSI y el p-value son:  0.26, 0.00

# %%
calcular('Uribia',2012,12)
# Out:
# La ENFICC 99% de  Ideam  es de  4.28
# La ENFICC 99% de  Nrel  es de  4.62
# La ENFICC 99% de  Nrel Ajustada  es de  4.37
# El error RMSEn es:  11.25 %
# El error MBE es:  2.96 %
# El valor del test KSI y el p-value son:  0.20, 0.02

# %%
calcular('Uribia',2015,12)
# Out:
# La ENFICC 99% de  Ideam  es de  4.28
# La ENFICC 99% de  Nrel  es de  4.62
# La ENFICC 99% de  Nrel Ajustada  es de  4.38
# El error RMSEn es:  11.22 %
# El error MBE es:  2.82 %
# El valor del test KSI y el p-value son:  0.20, 0.02

# %% [markdown]
# En el caso de el fenómeno del Niño del 2010 se presenta la ENFICC más baja (ENFICC 99% = 4) y la función de ajuste de datos presenta su mayor error (MBE = 5.55%). Lo anterior se le puede atribuir a que los datos de este periodo de tiempo no son los más adecuados para realizar un ajuste en una serie de 10 años, por lo que son alterados por la condiciones climáticas extremas.
#
# En conclusión se tiene mejores resultados del ajuste MCP cuando se trabaja con un periodo de tiempo lo suficientemente largo para disminuir el error asociado, sin embargo, no se debe extender mucho por la posible propagación de error asociada a la probabilidad de encontrar datos erroneos en un periodo de tiempo extenso.
#
# Por otra parte, la influencia de los fenómenos naturales (Niño y Niña) no tiene cambios significativos en la ENFICC calculada, pero si pueden inducir un aumento en el error entre los datos ajustados con MCP y los reales.
